# %%
import pandas as pd
from ucimlrepo import fetch_ucirepo

# %%
data = pd.read_csv("https://archive.ics.uci.edu/dataset/10/automobile.dat", sep='\t', names = ['price', 'highway-mpg', 'city-mpg', 'peak-rpm','horsepower','compression-ratio', 'stroke', 'bore','fuel-system', 'engine-size'])
data.head(10)
# Out:
#                                                price  highway-mpg city-mpg  \
# 0                                    <!DOCTYPE html>          NaN      NaN
# 1                <html lang="en" data-theme="light">          NaN      NaN
# 2                                             <head>          NaN      NaN
# 3                           <meta charset="UTF-8" />          NaN      NaN
# 4      <meta name="viewport" content="width=devic...          NaN      NaN
# 5      <meta name="description" content="Discover...          NaN      NaN
# 6            <link rel="icon" href="/favicon.ico" />          NaN      NaN
# 7      <link rel="apple-touch-icon" href="/apple-...          NaN      NaN
# 8      <!-- Provides metadata used when the app i...          NaN      NaN
# 9      <!-- See https://developers.google.com/web...          NaN      NaN
#
#   peak-rpm horsepower compression-ratio stroke bore  fuel-system  engine-size
# ...

# %%
# fetch dataset 
automobile = fetch_ucirepo(id=10) 
automobile
# Out:
# {'data': {'ids': None,
#   'features':        price  highway-mpg  city-mpg  peak-rpm  horsepower  compression-ratio  \
#   0    13495.0           27        21    5000.0       111.0                9.0
#   1    16500.0           27        21    5000.0       111.0                9.0
#   2    16500.0           26        19    5000.0       154.0                9.0
#   3    13950.0           30        24    5500.0       102.0               10.0
#   4    17450.0           22        18    5500.0       115.0                8.0
#   ..       ...          ...       ...       ...         ...                ...
#   200  16845.0           28        23    5400.0       114.0                9.5
#   201  19045.0           25        19    5300.0       160.0                8.7
#   202  21485.0           23        18    5500.0       134.0                8.8
#   203  22470.0           27        26    4800.0       106.0               23.0
# ...

# %%
# data (as pandas dataframes) 
X = automobile.data.features 
y = automobile.data.targets

# %%
X
# Out:
#        price  highway-mpg  city-mpg  peak-rpm  horsepower  compression-ratio  \
# 0    13495.0           27        21    5000.0       111.0                9.0
# 1    16500.0           27        21    5000.0       111.0                9.0
# 2    16500.0           26        19    5000.0       154.0                9.0
# 3    13950.0           30        24    5500.0       102.0               10.0
# 4    17450.0           22        18    5500.0       115.0                8.0
# ..       ...          ...       ...       ...         ...                ...
# 200  16845.0           28        23    5400.0       114.0                9.5
# 201  19045.0           25        19    5300.0       160.0                8.7
# 202  21485.0           23        18    5500.0       134.0                8.8
# 203  22470.0           27        26    4800.0       106.0               23.0
# 204  22625.0           25        19    5400.0       114.0                9.5
#
# ...
